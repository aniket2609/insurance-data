# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1=pd.read_csv('C:\\Users\\win10\\Downloads\\bank (1).csv')

# %%
df_1.head(10)
# Out:
#    Bank   DD  Withdrawals  Deposits  Branch Area in sqft  avg daily walkins
# 0     1  227          147       111                 2460                639
# 1     2  123           86        65                 3510                436
# 2     3  306          149        76                 2570                669
# 3     4  251          112       129                 3650                623
# 4     5  174          135       128                 3400                579
# 5     6  200          229        57                 3470                625
# 6     7  144           88       112                 3190                476
# 7     8  256          165        46                 2930                621
# 8     9  282          139       105                 2110                658
# 9    10  317          196        72                 3000                717

# %%
df_1.describe()
# Out:
#              Bank          DD  Withdrawals    Deposits  Branch Area in sqft  \
# count  515.000000  515.000000   515.000000  515.000000           515.000000
# mean   258.000000  232.252427   150.693204   81.687379          2934.669903
# std    148.811962   66.648815    56.897777   28.596912           437.062831
# min      1.000000  120.000000    10.000000   33.000000          1200.000000
# 25%    129.500000  169.500000   103.000000   58.000000          2675.000000
# 50%    258.000000  237.000000   152.000000   80.000000          2960.000000
# 75%    386.500000  291.000000   200.000000  105.000000          3300.000000
# max    515.000000  350.000000   247.000000  212.000000          3650.000000
#
#        avg daily walkins
# count         515.000000
# mean          598.603883
# std            83.487891
# min           380.000000
# 25%           537.500000
# 50%           601.000000
# 75%           657.500000
# max           838.000000

# %%
df_1.shape
# Out:
# (515, 6)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Bank                 515 non-null    int64
#  1   DD                   515 non-null    int64
#  2   Withdrawals          515 non-null    int64
#  3   Deposits             515 non-null    int64
#  4   Branch Area in sqft  515 non-null    int64
#  5   avg daily walkins    515 non-null    int64
# dtypes: int64(6)
# memory usage: 24.3 KB

# %%
df_1.duplicated().sum()
# Out:
# 0

# %%
df=df_1.drop('Bank',axis=1)

# %%
df
# Out:
#       DD  Withdrawals  Deposits  Branch Area in sqft  avg daily walkins
# 0    227          147       111                 2460                639
# 1    123           86        65                 3510                436
# 2    306          149        76                 2570                669
# 3    251          112       129                 3650                623
# 4    174          135       128                 3400                579
# ..   ...          ...       ...                  ...                ...
# 510  337          140       111                 2640                694
# 511  168          131        60                 2640                524
# 512  333           86       108                 2850                676
# 513  192          176        34                 2760                505
# 514  331          186        97                 2700                767
#
# [515 rows x 5 columns]

# %%
df.describe()
# Out:
#                DD  Withdrawals    Deposits  Branch Area in sqft  \
# count  515.000000   515.000000  515.000000           515.000000
# mean   232.252427   150.693204   81.687379          2934.669903
# std     66.648815    56.897777   28.596912           437.062831
# min    120.000000    10.000000   33.000000          1200.000000
# 25%    169.500000   103.000000   58.000000          2675.000000
# 50%    237.000000   152.000000   80.000000          2960.000000
# 75%    291.000000   200.000000  105.000000          3300.000000
# max    350.000000   247.000000  212.000000          3650.000000
#
#        avg daily walkins
# count         515.000000
# mean          598.603883
# std            83.487891
# min           380.000000
# 25%           537.500000
# 50%           601.000000
# 75%           657.500000
# max           838.000000

# %%
from scipy.cluster.hierarchy import dendrogram , linkage

# %%
ward_link=linkage(df,method='ward')

# %%
ward_link=linkage(df,method='ward')

# %%
dend=dendrogram(ward_link)

# %%
from scipy.cluster.hierarchy import fcluster

# %%
cluster_division=fcluster(ward_link,3, criterion='maxclust')

# %%
cluster_division
# Out:
# array([1, 2, 3, 2, 2, 2, 3, 3, 1, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2,
#        2, 1, 3, 3, 2, 3, 3, 1, 3, 1, 3, 3, 2, 3, 3, 3, 1, 3, 3, 3, 2, 3,
#        3, 1, 1, 2, 3, 3, 2, 3, 3, 1, 2, 1, 2, 3, 3, 2, 2, 3, 2, 3, 3, 3,
#        3, 1, 3, 3, 3, 1, 3, 3, 2, 2, 3, 3, 3, 1, 3, 3, 3, 2, 2, 3, 3, 2,
#        2, 3, 1, 2, 1, 3, 3, 3, 3, 1, 2, 3, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3,
#        3, 3, 3, 2, 1, 3, 3, 3, 3, 2, 3, 3, 2, 2, 3, 3, 3, 2, 2, 3, 3, 3,
#        3, 3, 1, 3, 2, 3, 1, 3, 2, 3, 3, 1, 1, 3, 3, 3, 1, 2, 3, 1, 3, 2,
#        3, 3, 3, 3, 3, 3, 2, 1, 1, 3, 1, 3, 2, 3, 1, 2, 3, 2, 3, 1, 3, 3,
#        1, 3, 1, 1, 2, 3, 2, 2, 1, 2, 3, 3, 2, 3, 2, 3, 3, 3, 1, 3, 3, 3,
#        3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 3, 2, 3, 2, 3,
#        2, 3, 3, 3, 1, 3, 2, 3, 3, 2, 2, 3, 3, 3, 3, 1, 3, 3, 2, 3, 3, 3,
#        1, 3, 1, 3, 2, 2, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 1, 2, 3, 3,
#        2, 3, 1, 3, 3, 3, 3, 2, 3, 3, 3, 3, 2, 1, 3, 3, 3, 3, 3, 3, 2, 3,
# ...

# %%
df_1['added_cluster']=cluster_division
df['added_cluster']=cluster_division
df_1
# Out:
#      Bank   DD  Withdrawals  Deposits  Branch Area in sqft  avg daily walkins  \
# 0       1  227          147       111                 2460                639
# 1       2  123           86        65                 3510                436
# 2       3  306          149        76                 2570                669
# 3       4  251          112       129                 3650                623
# 4       5  174          135       128                 3400                579
# ..    ...  ...          ...       ...                  ...                ...
# 510   511  337          140       111                 2640                694
# 511   512  168          131        60                 2640                524
# 512   513  333           86       108                 2850                676
# 513   514  192          176        34                 2760                505
# 514   515  331          186        97                 2700                767
#
#      added_cluster
# ...

# %%
df
# Out:
#       DD  Withdrawals  Deposits  Branch Area in sqft  avg daily walkins  \
# 0    227          147       111                 2460                639
# 1    123           86        65                 3510                436
# 2    306          149        76                 2570                669
# 3    251          112       129                 3650                623
# 4    174          135       128                 3400                579
# ..   ...          ...       ...                  ...                ...
# 510  337          140       111                 2640                694
# 511  168          131        60                 2640                524
# 512  333           86       108                 2850                676
# 513  192          176        34                 2760                505
# 514  331          186        97                 2700                767
#
#      added_cluster
# 0                1
# 1                2
# 2                3
# 3                2
# ...

# %%
pivot=pd.pivot_table(df, index='added_cluster')

# %%
pivot
# Out:
#                Branch Area in sqft          DD   Deposits  Withdrawals  \
# added_cluster
# 1                      2192.037037  250.098765  83.802469   177.543210
# 2                      3449.531250  230.757812  82.781250   145.210938
# 3                      2915.882353  228.153595  80.669935   145.879085
#
#                avg daily walkins
# added_cluster
# 1                     640.728395
# 2                     594.218750
# 3                     589.287582

# %%
df_1['added_cluster'].value_counts()
# Out:
# 3    306
# 2    128
# 1     81
# Name: added_cluster, dtype: int64

# %%
pivot_1=pd.pivot_table(df_1, index='added_cluster')

# %%
pivot_1
# Out:
#                      Bank  Branch Area in sqft          DD   Deposits  \
# added_cluster
# 1              256.049383          2192.037037  250.098765  83.802469
# 2              265.554688          3449.531250  230.757812  82.781250
# 3              255.356209          2915.882353  228.153595  80.669935
#
#                Withdrawals  avg daily walkins
# added_cluster
# 1               177.543210         640.728395
# 2               145.210938         594.218750
# 3               145.879085         589.287582

# %%
df_1.to_csv('C:\\Users\\win10\\Downloads\\bank (1).csv')
