# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel('D:\Ml dataset\life.xlsx',sheet_name='Sales')

# %%
df.columns
# Out:
# Index(['CustID', 'AgentBonus', 'Age', 'CustTenure', 'Channel', 'Occupation',
#        'EducationField', 'Gender', 'ExistingProdType', 'Designation',
#        'NumberOfPolicy', 'MaritalStatus', 'MonthlyIncome', 'Complaint',
#        'ExistingPolicyTenure', 'SumAssured', 'Zone', 'PaymentMethod',
#        'LastMonthCalls', 'CustCareScore'],
#       dtype='object')

# %%
df.shape
# Out:
# (4520, 20)

# %%
df.head()
# Out:
#     CustID  AgentBonus  Age  CustTenure              Channel      Occupation  \
# 0  7000000        4409   22          13                Agent        Salaried
# 1  7000001        2214   11           2  Third Party Partner        Salaried
# 2  7000002        4273   26           4                Agent     Free Lancer
# 3  7000003        1791   11          13  Third Party Partner        Salaried
# 4  7000004        2955    6          13                Agent  Small Business
#
#   EducationField   Gender  ExistingProdType Designation  NumberOfPolicy  \
# 0       Graduate   Female                 3     Manager             2.0
# 1       Graduate     Male                 4     Manager             4.0
# 2  Post Graduate     Male                 4         Exe             3.0
# 3       Graduate  Fe male                 3   Executive             3.0
# 4             UG     Male                 3   Executive             4.0
#
# ...

# %%
df = df.drop(['CustID'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4520 entries, 0 to 4519
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AgentBonus            4520 non-null   int64
#  1   Age                   4520 non-null   int64
#  2   CustTenure            4520 non-null   int64
#  3   Channel               4520 non-null   object
#  4   Occupation            4520 non-null   object
#  5   EducationField        4520 non-null   object
#  6   Gender                4520 non-null   object
#  7   ExistingProdType      4520 non-null   int64
#  8   Designation           4520 non-null   object
#  9   NumberOfPolicy        4475 non-null   float64
#  10  MaritalStatus         4520 non-null   object
#  11  MonthlyIncome         4520 non-null   int64
#  12  Complaint             4520 non-null   int64
#  13  ExistingPolicyTenure  4336 non-null   float64
#  14  SumAssured            4520 non-null   int64
# ...

# %%
df.describe()
# Out:
#         AgentBonus          Age   CustTenure  ExistingProdType  \
# count  4520.000000  4520.000000  4520.000000       4520.000000
# mean   4077.838274    14.405752    14.397566          3.688938
# std    1403.321711     8.771646     8.741177          1.015769
# min    1605.000000     2.000000     2.000000          1.000000
# 25%    3027.750000     8.000000     8.000000          3.000000
# 50%    3911.500000    13.000000    13.000000          4.000000
# 75%    4867.250000    19.000000    19.000000          4.000000
# max    9608.000000    58.000000    57.000000          6.000000
#
#        NumberOfPolicy  MonthlyIncome    Complaint  ExistingPolicyTenure  \
# count     4475.000000    4520.000000  4520.000000           4336.000000
# mean         3.565363   22823.253097     0.287168              4.130074
# std          1.455926    4764.892420     0.452491              3.346386
# min          1.000000   16009.000000     0.000000              1.000000
# ...

# %%
df.isnull().sum()
# Out:
# AgentBonus                0
# Age                       0
# CustTenure                0
# Channel                   0
# Occupation                0
# EducationField            0
# Gender                    0
# ExistingProdType          0
# Designation               0
# NumberOfPolicy           45
# MaritalStatus             0
# MonthlyIncome             0
# Complaint                 0
# ExistingPolicyTenure    184
# SumAssured                0
# Zone                      0
# PaymentMethod             0
# LastMonthCalls            0
# CustCareScore             0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                        count           mean            std       min  \
# AgentBonus            4520.0    4077.838274    1403.321711    1605.0
# Age                   4520.0      14.405752       8.771646       2.0
# CustTenure            4520.0      14.397566       8.741177       2.0
# ExistingProdType      4520.0       3.688938       1.015769       1.0
# NumberOfPolicy        4475.0       3.565363       1.455926       1.0
# MonthlyIncome         4520.0   22823.253097    4764.892420   16009.0
# Complaint             4520.0       0.287168       0.452491       0.0
# ExistingPolicyTenure  4336.0       4.130074       3.346386       1.0
# SumAssured            4520.0  618601.989159  242117.248303  168536.0
# LastMonthCalls        4520.0       4.626991       3.620132       0.0
# CustCareScore         4520.0       3.066814       1.375007       1.0
#
#                             25%       50%        75%        max
# AgentBonus              3027.75    3911.5    4867.25     9608.0
# ...

# %%
sns.pairplot(df,diag_kind='kde')

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True,)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x = df['PaymentMethod'])
plt.show()

# %%
sns.countplot(x = df['EducationField'])
plt.figure(figsize=(10,6))
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x = df['MonthlyIncome'])
plt.show()

# %%
sns.countplot(x = df['MaritalStatus'], palette='pastel')
plt.show()

# %%
sns.countplot(x = df['Gender'])
plt.show()

# %%
# Handle categorical variables (example: one-hot encoding)
categorical_columns = ['Channel', 'Occupation', 'EducationField', 'Gender', 'ExistingProdType', 'Designation', 'MaritalStatus', 'Zone', 'PaymentMethod','NumberOfPolicy','ExistingPolicyTenure']
df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# %%
df
# Out:
#       AgentBonus  Age  CustTenure  MonthlyIncome  Complaint  SumAssured  \
# 0           4409   22          13          20993          1      806761
# 1           2214   11           2          20130          0      294502
# 2           4273   26           4          17090          1      578976
# 3           1791   11          13          17909          1      268635
# 4           2955    6          13          18468          0      366405
# ...          ...  ...         ...            ...        ...         ...
# 4515        3953    4           8          26355          0      636473
# 4516        2939    9           9          20991          0      296813
# 4517        3792   23          23          21606          0      667371
# 4518        4816   10          10          20068          0      943999
# 4519        4764   14          10          23820          0      700308
#
#       LastMonthCalls  CustCareScore  Channel_Online  \
# ...

# %%
df.corr()
# Out:
#                            AgentBonus       Age  CustTenure  MonthlyIncome  \
# AgentBonus                   1.000000  0.552344    0.555930       0.566688
# Age                          0.552344  1.000000    0.323733       0.327965
# CustTenure                   0.555930  0.323733    1.000000       0.318388
# MonthlyIncome                0.566688  0.327965    0.318388       1.000000
# Complaint                    0.014281  0.020257    0.004641      -0.005197
# ...                               ...       ...         ...            ...
# ExistingPolicyTenure_20.0    0.055507  0.056595    0.012588       0.071713
# ExistingPolicyTenure_21.0    0.032230  0.048498    0.048681      -0.003801
# ExistingPolicyTenure_22.0    0.059096  0.031412    0.030337       0.024384
# ExistingPolicyTenure_23.0    0.039418  0.002704    0.041873      -0.003801
# ExistingPolicyTenure_25.0    0.044348  0.017969    0.060595       0.045984
#
#                            Complaint  SumAssured  LastMonthCalls  \
# ...

# %%
df.isnull().sum()
# Out:
# AgentBonus                   0
# Age                          0
# CustTenure                   0
# MonthlyIncome                0
# Complaint                    0
#                             ..
# ExistingPolicyTenure_20.0    0
# ExistingPolicyTenure_21.0    0
# ExistingPolicyTenure_22.0    0
# ExistingPolicyTenure_23.0    0
# ExistingPolicyTenure_25.0    0
# Length: 69, dtype: int64

# %%
X=df.drop('AgentBonus',axis=1)
X
# Out:
#       Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 0      22          13          20993          1      806761               5
# 1      11           2          20130          0      294502               7
# 2      26           4          17090          1      578976               0
# 3      11          13          17909          1      268635               0
# 4       6          13          18468          0      366405               2
# ...   ...         ...            ...        ...         ...             ...
# 4515    4           8          26355          0      636473               9
# 4516    9           9          20991          0      296813               1
# 4517   23          23          21606          0      667371               4
# 4518   10          10          20068          0      943999               1
# 4519   14          10          23820          0      700308               1
#
# ...

# %%
X.head(5)
# Out:
#    Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 0   22          13          20993          1      806761               5
# 1   11           2          20130          0      294502               7
# 2   26           4          17090          1      578976               0
# 3   11          13          17909          1      268635               0
# 4    6          13          18468          0      366405               2
#
#    CustCareScore  Channel_Online  Channel_Third Party Partner  \
# 0              2               0                            0
# 1              3               0                            1
# 2              3               0                            0
# 3              5               0                            1
# 4              5               0                            0
#
#    Occupation_Laarge Business  ...  ExistingPolicyTenure_15.0  \
# 0                           0  ...                          0
# ...

# %%
Y=df.pop('AgentBonus')

# %%
Y.head(5)
# Out:
# 0    4409
# 1    2214
# 2    4273
# 3    1791
# 4    2955
# Name: AgentBonus, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X, Y, test_size=0.30, random_state=1)

# %%
X_train.head(3)
# Out:
#       Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 2461   12          16          20742          1      480800               1
# 3681   31          15          23398          0      617707               2
# 1309   15           6          16232          0      453360               0
#
#       CustCareScore  Channel_Online  Channel_Third Party Partner  \
# 2461              4               0                            1
# 3681              4               0                            0
# 1309              5               0                            0
#
#       Occupation_Laarge Business  ...  ExistingPolicyTenure_15.0  \
# 2461                           1  ...                          0
# 3681                           0  ...                          0
# 1309                           0  ...                          0
#
#       ExistingPolicyTenure_16.0  ExistingPolicyTenure_17.0  \
# 2461                          0                          0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regression_model=LinearRegression()

# %%
regression_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train,Y_train)
# Out:
# 0.8167175670298638

# %%
X_test.columns
# Out:
# Index(['Age', 'CustTenure', 'MonthlyIncome', 'Complaint', 'SumAssured',
#        'LastMonthCalls', 'CustCareScore', 'Channel_Online',
#        'Channel_Third Party Partner', 'Occupation_Laarge Business',
#        'Occupation_Large Business', 'Occupation_Salaried',
#        'Occupation_Small Business', 'EducationField_Engineer',
#        'EducationField_Graduate', 'EducationField_MBA',
#        'EducationField_Post Graduate', 'EducationField_UG',
#        'EducationField_Under Graduate', 'Gender_Female', 'Gender_Male',
#        'ExistingProdType_2', 'ExistingProdType_3', 'ExistingProdType_4',
#        'ExistingProdType_5', 'ExistingProdType_6', 'Designation_Exe',
#        'Designation_Executive', 'Designation_Manager',
#        'Designation_Senior Manager', 'Designation_VP', 'MaritalStatus_Married',
#        'MaritalStatus_Single', 'MaritalStatus_Unmarried', 'Zone_North',
#        'Zone_South', 'Zone_West', 'PaymentMethod_Monthly',
# ...

# %%
regression_model.coef_
# Out:
# array([ 2.18632235e+01,  2.35106921e+01,  2.34502409e-02,  4.04692829e+01,
#         3.45360552e-03, -2.95875867e+00,  9.38287937e+00,  3.03684677e+01,
#         1.05848952e+01, -6.70176098e+02, -7.28128984e+02, -6.11956136e+02,
#        -7.37718665e+02, -3.86161760e+01, -1.15425333e+02, -1.19744998e+02,
#        -1.00071522e+02,  1.64358369e+00,  5.66249591e+00,  2.92379501e+01,
#         4.57451414e+01,  8.77090044e+01, -9.03092134e+01, -2.40052466e+01,
#         6.54768120e-01,  8.38254199e+00, -8.83738954e+02, -4.55022280e+02,
#        -4.43936608e+02, -2.35304829e+02,  7.80481975e+01, -4.36974806e+01,
#         2.70980578e+01, -1.38962317e+02,  5.04992306e+01,  1.94655102e+02,
#         5.06343501e+01, -3.16036460e+01,  1.94234637e+01, -8.12005892e+01,
#         5.14296413e+01,  7.34600760e+01,  6.33533477e+01,  6.45384476e+01,
#         4.31831369e+01,  1.06214677e+02,  1.16071883e+02,  9.19296663e+01,
# ...

# %%
regression_model.intercept_
# Out:
# 1630.3868509482782

# %%
df.head(5)
# Out:
#    Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 0   22          13          20993          1      806761               5
# 1   11           2          20130          0      294502               7
# 2   26           4          17090          1      578976               0
# 3   11          13          17909          1      268635               0
# 4    6          13          18468          0      366405               2
#
#    CustCareScore  Channel_Online  Channel_Third Party Partner  \
# 0              2               0                            0
# 1              3               0                            1
# 2              3               0                            0
# 3              5               0                            1
# 4              5               0                            0
#
#    Occupation_Laarge Business  ...  ExistingPolicyTenure_15.0  \
# 0                           0  ...                          0
# ...

# %%
from sklearn.linear_model import LinearRegression 
regression_model=LinearRegression()
regression_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train,Y_train)
# Out:
# 0.8167175670298638

# %%
regression_model.score(X_test,Y_test)
# Out:
# 0.7987573606587277

# %%
regression_model.coef_
# Out:
# array([ 2.18632235e+01,  2.35106921e+01,  2.34502409e-02,  4.04692829e+01,
#         3.45360552e-03, -2.95875867e+00,  9.38287937e+00,  3.03684677e+01,
#         1.05848952e+01, -6.70176098e+02, -7.28128984e+02, -6.11956136e+02,
#        -7.37718665e+02, -3.86161760e+01, -1.15425333e+02, -1.19744998e+02,
#        -1.00071522e+02,  1.64358369e+00,  5.66249591e+00,  2.92379501e+01,
#         4.57451414e+01,  8.77090044e+01, -9.03092134e+01, -2.40052466e+01,
#         6.54768120e-01,  8.38254199e+00, -8.83738954e+02, -4.55022280e+02,
#        -4.43936608e+02, -2.35304829e+02,  7.80481975e+01, -4.36974806e+01,
#         2.70980578e+01, -1.38962317e+02,  5.04992306e+01,  1.94655102e+02,
#         5.06343501e+01, -3.16036460e+01,  1.94234637e+01, -8.12005892e+01,
#         5.14296413e+01,  7.34600760e+01,  6.33533477e+01,  6.45384476e+01,
#         4.31831369e+01,  1.06214677e+02,  1.16071883e+02,  9.19296663e+01,
# ...

# %%
regression_model.intercept_
# Out:
# 1630.3868509482782

# %%
regression_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_train.columns
# Out:
# Index(['Age', 'CustTenure', 'MonthlyIncome', 'Complaint', 'SumAssured',
#        'LastMonthCalls', 'CustCareScore', 'Channel_Online',
#        'Channel_Third Party Partner', 'Occupation_Laarge Business',
#        'Occupation_Large Business', 'Occupation_Salaried',
#        'Occupation_Small Business', 'EducationField_Engineer',
#        'EducationField_Graduate', 'EducationField_MBA',
#        'EducationField_Post Graduate', 'EducationField_UG',
#        'EducationField_Under Graduate', 'Gender_Female', 'Gender_Male',
#        'ExistingProdType_2', 'ExistingProdType_3', 'ExistingProdType_4',
#        'ExistingProdType_5', 'ExistingProdType_6', 'Designation_Exe',
#        'Designation_Executive', 'Designation_Manager',
#        'Designation_Senior Manager', 'Designation_VP', 'MaritalStatus_Married',
#        'MaritalStatus_Single', 'MaritalStatus_Unmarried', 'Zone_North',
#        'Zone_South', 'Zone_West', 'PaymentMethod_Monthly',
# ...

# %%
data_train=pd.concat([X_train,Y_train], axis=1)

# %%
data_train.head(5)
# Out:
#       Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 2461   12          16          20742          1      480800               1
# 3681   31          15          23398          0      617707               2
# 1309   15           6          16232          0      453360               0
# 4254    5          16          23536          0      282197               8
# 1335    8          17          17269          0      750165               1
#
#       CustCareScore  Channel_Online  Channel_Third Party Partner  \
# 2461              4               0                            1
# 3681              4               0                            0
# 1309              5               0                            0
# 4254              3               1                            0
# 1335              5               0                            0
#
#       Occupation_Laarge Business  ...  ExistingPolicyTenure_16.0  \
# ...

# %%
# Using Statsmodel 
data_train=pd.concat([X_train,Y_train], axis=1)
data_train.head(5)
# Out:
#       Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 2461   12          16          20742          1      480800               1
# 3681   31          15          23398          0      617707               2
# 1309   15           6          16232          0      453360               0
# 4254    5          16          23536          0      282197               8
# 1335    8          17          17269          0      750165               1
#
#       CustCareScore  Channel_Online  Channel_Third Party Partner  \
# 2461              4               0                            1
# 3681              4               0                            0
# 1309              5               0                            0
# 4254              3               1                            0
# 1335              5               0                            0
#
#       Occupation_Laarge Business  ...  ExistingPolicyTenure_16.0  \
# ...

# %%
regression_model.fit(X_test,Y_test)
# Out:
# LinearRegression()

# %%
regression_model.score(X_test,Y_test)
# Out:
# 0.8128839606786129

# %%
regression_model.fit(X_test, Y_test)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_test.columns):
    print("The coefficient for{} is{}".format(col_name, regression_model.coef_[idx]))
# Out:
# The coefficient forAge is25.698071578448623
# The coefficient forCustTenure is26.80564786004356
# The coefficient forMonthlyIncome is0.020305822081967892
# The coefficient forComplaint is8.346370566019324
# The coefficient forSumAssured is0.0033560263481149377
# The coefficient forLastMonthCalls is0.9947226707745358
# The coefficient forCustCareScore is-5.100658286631472
# The coefficient forChannel_Online is-26.1069024819423
# The coefficient forChannel_Third Party Partner is3.37400986526751
# The coefficient forOccupation_Laarge Business is232.3403154931846
# The coefficient forOccupation_Large Business is74.18301099179536
# The coefficient forOccupation_Salaried is-180.0948628043925
# The coefficient forOccupation_Small Business is-126.42846368063168
# The coefficient forEducationField_Engineer is-155.9455539327658
# The coefficient forEducationField_Graduate is138.67029482342133
# The coefficient forEducationField_MBA is-35.92055222692832
# ...

# %%
# Using Statsmodel 
data_train=pd.concat([X_test,Y_test], axis=1)
data_train.head(5)
# Out:
#       Age  CustTenure  MonthlyIncome  Complaint  SumAssured  LastMonthCalls  \
# 610    11          23          22756          0      785082               4
# 1519   20           7          34517          0     1200156               6
# 1620    7          15          18697          0      430218               8
# 2031   13          22          21385          1      884697               7
# 494    12          14          17259          0      253707               0
#
#       CustCareScore  Channel_Online  Channel_Third Party Partner  \
# 610               2               0                            1
# 1519              1               0                            0
# 1620              3               0                            0
# 2031              5               0                            1
# 494               2               0                            0
#
#       Occupation_Laarge Business  ...  ExistingPolicyTenure_16.0  \
# ...

# %%
# To check RMSE for test data and plot in a graph

# %%
y_pred=regression_model.predict(X_test)

# %%
y_pred
# Out:
# array([4600.23094201, 6668.56470144, 2949.88882724, ..., 3045.78372146,
#        2849.83134811, 5303.83095745])

# %%
import math

# %%
Squared_difference= (Y_test-y_pred)**2

# %%
Squared_difference
# Out:
# 610     1.185418e+06
# 1519    1.222455e+04
# 1620    2.692456e+05
# 2031    2.465600e+05
# 494     9.887404e+02
#             ...
# 2124    3.130393e+05
# 3220    2.754556e+05
# 1851    6.802682e+05
# 1065    1.323732e+05
# 462     5.503132e+05
# Name: AgentBonus, Length: 1356, dtype: float64

# %%
mse=np.mean(Squared_difference)

# %%
mse
# Out:
# 365280.2594031958

# %%
RMSE= (mse)**0.5

# %%
RMSE
# Out:
# 604.3841985055498

# %%
Y_test
# Out:
# 610     5689
# 1519    6558
# 1620    2431
# 2031    4491
# 494     2416
#         ...
# 2124    5176
# 3220    2379
# 1851    2221
# 1065    2486
# 462     4562
# Name: AgentBonus, Length: 1356, dtype: int64

# %%
## Ploting the test data and predicted test data



plt.scatter(Y_test, y_pred)
